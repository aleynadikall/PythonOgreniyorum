# %% [markdown]
# #### Hipotez Testi Nedir?

# %% [markdown]
# Bir inanışı (bir savı, bir tahmini vs.) test etmek için kullanılan istatistiksel bir tekniktir.

# %% [markdown]
# #### Hipotezler ve Türleri

# %% [markdown]
# * H0: 0 Hipotezi (Parametrelere belirli değerler verilerek)
# * H1: Alternatif Hipotez

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ###### Yönlü Hipotez

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# #### Hata Tipleri

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)
