# %% [markdown]
# ### Güven Aralığı

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# * Güven aralığı genelde %95 kabul edilir.
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# #### İş Uygulaması: Fiyat Stratejisi Karar Destek Sistemi

# %%
# Problem: CEO fiyat belirleme konusunda bilimsel bir dayanak ve esneklik isteniyor.
# Detaylar
# Satıcı,alıcı ve bir ürün var.
# Alıcılara ürüne ne kadar ücret öderdiniz diye soruluyor.
# Optimum fiyat bilimsel ve esnek olarak bulunmak isteniyor.

# %%
import numpy as np
fiyatlar = np.random.randint(10, 110, 1000)

# %%
fiyatlar.mean()
# Out:
# 58.857

# %%
import statsmodels.stats.api as sms

# %%
sms.DescrStatsW(fiyatlar).tconfint_mean()
# Out:
# (57.051469769670334, 60.662530230329665)
