# %% [markdown]
# ### Örnek Teorisi

# %% [markdown]
# "Without a grounding in statistics, a Data Scientist is a Data Lab Assistant."

# %% [markdown]
# İstatistik veri biliminin "bilim" makine öğrenmesinin "öğrenme" kısmıdır.

# %% [markdown]
# #### Örneklem

# %% [markdown]
# ![Screenshot_43.png](attachment:Screenshot_43.png)

# %% [markdown]
# ![Screenshot_44.png](attachment:Screenshot_44.png)

# %% [markdown]
# #### Örneklem Dağılımı

# %% [markdown]
# ![Screenshot_45.png](attachment:Screenshot_45.png)

# %% [markdown]
# #### Merkezi Limit Teoremi

# %% [markdown]
# ![Screenshot_47.png](attachment:Screenshot_47.png)

# %% [markdown]
# ![Screenshot_46.png](attachment:Screenshot_46.png)

# %% [markdown]
# ### Uygulama

# %%
# Bir ilçedeki kişilerin yaş ortalaması hakkında bir çalışmak yapmak istiyoruz. 
# Herkesle görüşmek yerine x tane kişiden y tane örneklem çekip buna göre hesaplamalar yapalım.

# %%
import numpy as np

# %%
populasyon = np.random.randint(0, 80, 10000)

# %%
populasyon[0:10]
# Out:
# array([13,  7, 14, 63, 15, 12, 76, 21, 74,  2])

# %%
# örneklem çekimi
np.random.seed(10) #oncesinde bir seed ayarı çekmeliyiz. 

# Bunu yapmamızın sebebi tekrar örnek çekmek istediğimizde aynı yapıya göre örneklem çekecek.
# Tum orneklemler aynı yapıya göre seçilecek.

orneklem = np.random.choice(a = populasyon, size = 100)
orneklem[0:10]
# Out:
# array([64, 39, 77, 69, 21, 74, 11, 43, 72, 57])

# %%
orneklem.mean()
# Out:
# 38.56

# %%
populasyon.mean()
# Out:
# 39.1292

# %%
np.random.seed(115)
orneklem2 = np.random.choice(a = populasyon, size = 100)
orneklem2[0:10]
# Out:
# array([61, 48, 71, 24, 13, 50, 54, 21, 68, 41])

# %%
orneklem2.mean()
# Out:
# 38.73

# %% [markdown]
# #### Örneklem Dağılımı

# %%
# Ben bu populasyon içinden y tane örneklem çektim. Peki hangi y tanesini çektim? Farklı farklı y taneler de çekebilirdim.
np.random.seed(10)
orneklem_1 = np.random.choice(a = populasyon, size = 100)
orneklem_2 = np.random.choice(a = populasyon, size = 100)
orneklem_3 = np.random.choice(a = populasyon, size = 100)
orneklem_4 = np.random.choice(a = populasyon, size = 100)
orneklem_5 = np.random.choice(a = populasyon, size = 100)
orneklem_6 = np.random.choice(a = populasyon, size = 100)
orneklem_7 = np.random.choice(a = populasyon, size = 100)
orneklem_8 = np.random.choice(a = populasyon, size = 100)
orneklem_9 = np.random.choice(a = populasyon, size = 100)
orneklem_10 = np.random.choice(a = populasyon, size = 100)

# %%
(orneklem_1.mean() + orneklem_2.mean() + orneklem_3.mean() + orneklem_4.mean() 
+ orneklem_5.mean() + orneklem_6.mean() + orneklem_7.mean() + orneklem_8.mean() 
+ orneklem_9.mean() + orneklem_10.mean()) / 10
# Out:
# 39.477000000000004
