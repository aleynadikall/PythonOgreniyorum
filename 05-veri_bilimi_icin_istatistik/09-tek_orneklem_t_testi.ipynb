# %% [markdown]
# #### Tek Örneklem T Testi

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# #### Tek Örneklem T Testi: Hipotezler

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# #### Tek Örneklem T Testi: Test İstatistiği

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# #### Tek Örneklem T Testi: Varsayım

# %% [markdown]
# * Normal Dağılım

# %% [markdown]
# #### İş Uygulaması: Ürün Satın Alma Adım Optimizasyonu

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %% [markdown]
# ![Screenshot_3.png](attachment:Screenshot_3.png)

# %% [markdown]
# ![Screenshot_4.png](attachment:Screenshot_4.png)

# %% [markdown]
# ![Screenshot_6.png](attachment:Screenshot_6.png)

# %% [markdown]
# ![Screenshot_5.png](attachment:Screenshot_5.png)

# %% [markdown]
# ![Screenshot_8.png](attachment:Screenshot_8.png)

# %% [markdown]
# ![Screenshot_9.png](attachment:Screenshot_9.png)

# %% [markdown]
# ![Screenshot_10.png](attachment:Screenshot_10.png)

# %% [markdown]
# #### İş Uygulaması: Web Sitesinde Geçirilen Sürenin Testi

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_1.png](attachment:Screenshot_1.png)

# %% [markdown]
# ![Screenshot_2.png](attachment:Screenshot_2.png)

# %%
import numpy as np

olcumler = np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119,
                    157, 145, 127, 244, 163, 114, 145, 65, 112, 185, 202, 146,
                    203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110,
                    216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])

# %%
olcumler[0:10]
# Out:
# array([ 17, 160, 234, 149, 145, 107, 197,  75, 201, 225])

# %%
import scipy.stats as stats

# %%
stats.describe(olcumler)
# Out:
# DescribeResult(nobs=50, minmax=(17, 251), mean=154.38, variance=2578.0363265306123, skewness=-0.32398897278694483, kurtosis=-0.05849823498415985)

# %% [markdown]
# ##### Tek Örneklem T Testi Varsayım Kontrolü

# %%
# varsayımlar
# normallik varsayımı

# %%
# histogram
import pandas as pd
pd.DataFrame(olcumler).plot.hist();
# çok ciddi bir bozukluk gözükmemektedir, dağılımın normal olduğu izlenimi verilmektedir.

# %%
# qqplot
import pylab
stats.probplot(olcumler, dist = 'norm', plot = pylab)
pylab.show()

# %%
# Shapiro-Wilks Testi

# %% [markdown]
# * H0 : Örnek değılımı ile teorik normal dağılım arasında istatistil olarak anlamlı bir farklılık yoktur.
# * H1 : .... fark vardır.

# %%
from scipy.stats import shapiro

# %%
shapiro(olcumler)
# Out:
# ShapiroResult(statistic=0.9853105545043945, pvalue=0.7848747968673706)

# %%
print("T Hesap İstatistiği: " + str(shapiro(olcumler)[0]))
print("Hesaplanan p-value: " + str(shapiro(olcumler)[1]))
# Out:
# T Hesap İstatistiği: 0.9853105545043945
# Hesaplanan p-value: 0.7848747968673706

# %% [markdown]
# * Bu duruma göre H0 hipotezi reddedilemez. Çünkü pvalue değerimiz alfa değerinden küçük değildir ve Örnek değılımı ile teorik normal dağılım arasında istatistil olarak anlamlı bir farklılık yoktur.
# * Bu nedenle parametrik bir test olan tek örneklem t testini uygulayabiliriz.

# %%
# Hipotez Testinin Uygulanması
stats.ttest_1samp(olcumler, popmean = 170)
# Out:
# Ttest_1sampResult(statistic=-2.1753117985877966, pvalue=0.034460415195071446)

# %% [markdown]
# H0: web sitemizde geçirilen ortalama süre 170'tir.
#
# H1: ... değildir.

# %% [markdown]
# * Çıkan p-value değeri başta bahsettiğimiz kabul edilebilir hata değeri olan alfa değerinden küçük olduğu için H0 hipotezi reddedilir. Yani web sitesinde geçirilen ortalama süre 170 değildir, daha küçük bir değerdir.
